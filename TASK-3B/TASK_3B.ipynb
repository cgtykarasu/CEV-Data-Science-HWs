# %%
####################################
#      DATA SCIENCE BOOTCAMP       #
# File name : TASK-3B.ipynb        #
# Author    : Çağatay KARASU       #
####################################

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data_all = pd.read_csv("MRI_and_CDRinfo_Values_X_train.csv")
data_all
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (22,24,28,41,44,46,51,61,63,65,67,69,71,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,167,177,205,208,213,216,219,223,225,227,229,231,233,235,237,239,241,243,245,249,251,253,380,382,402,404,406,551,648,651,654,689,751,770,772,774,782,843,898,899,921,943,946,964,965,1176) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      Unnamed: 0  Unnamed: 0.1  index_x    NACCID_x  NACCADC_x PACKET  FORMVER  \
# 0          1970          1970   116428  NACC831508       6518      I      1.0
# 1          1146          1146   110463  NACC719761       6499      I      2.0
# 2           675           675   106548  NACC979197       6061      F      2.0
# 3          1268          1268   111371  NACC917131       6499      I      2.0
# 4          2323          2323   161286  NACC056098       9661      F      2.0
# ..          ...           ...      ...         ...        ...    ...      ...
# 515         817           817   107868  NACC222132       6499      I      2.0
# 516        1570          1570   113572  NACC350169       6518      I      2.0
# 517         433           433    93373  NACC327046       5783      F      2.0
# 518        1418          1418   112501  NACC146151       6518      I      2.0
# 519        1428          1428   112574  NACC154876       6518      I      2.0
#
#      VISITMO  VISITDAY  VISITYR  ...  RSUPPARM  RSUPTEM  RSUPTEMM  RSUPMAR  \
# 0          5        23     2007  ...    0.9674   9.7215    2.1089   5.2785
# 1          9        24     2010  ...    1.5867  15.1130    2.1134  12.2880
# 2          7        18     2012  ...    1.2816  14.1317    2.2958   6.9755
# 3          2        21     2013  ...    1.6097  16.3510    2.0591   9.3860
# 4          1         8     2015  ...    1.7000  13.7700    2.1000  11.1200
# ..       ...       ...      ...  ...       ...      ...       ...      ...
# 515       10        18     2013  ...    1.3206  12.4100    1.9436   9.6460
# 516        7        14     2009  ...    1.4095  14.1347    2.2614   8.5959
# 517        1         8     2009  ...    2.3480  12.2270    2.6044   8.0750
# 518        4        27     2010  ...    1.1883  14.1980    2.3691   7.5203
# 519        5         6     2013  ...       NaN      NaN       NaN      NaN
#
#      RSUPMARM  RTRTEM  RTRTEMM  NACCNMRI_y  NACCVNUM_y  original_ind_y
# 0      1.1998  0.3315   0.3810         1.0         1.0          5342.0
# 1      1.8935  0.9070   1.8444         1.0         1.0          7855.0
# 2      1.7738  0.7716   1.5066         3.0         3.0          1948.0
# 3      1.7700  1.2190   1.9347         1.0         1.0          8348.0
# 4      2.1400  1.3100   1.5200         1.0         8.0            28.0
# ..        ...     ...      ...         ...         ...             ...
# 515    1.7066  0.9310   1.6959         1.0         1.0          8488.0
# 516    1.7112  0.9899   1.1929         2.0         1.0          4893.0
# 517    2.1037  0.9910   1.8489         1.0         2.0          3654.0
# 518    1.3900  1.0715   1.1006         2.0         1.0          4945.0
# 519       NaN     NaN      NaN         NaN         NaN             NaN
#
# [520 rows x 1380 columns]

# %%
data_labels = pd.read_csv("CDR_Values_y_train.csv")
data_labels["HIP_VOL"] = data_all["HIPPOVOL"]
data_labels
# Out:
#       Unnamed: 0  CDRGLOB  HIP_VOL
# 0           1970        0    5.196
# 1           1146        0    6.894
# 2            675        0    6.286
# 3           1268        2    5.589
# 4           2323        0    7.410
# ...          ...      ...      ...
# 1583         984        1      NaN
# 1584        1325        1      NaN
# 1585         788        2      NaN
# 1586         195        1      NaN
# 1587        1206        0      NaN
#
# [1588 rows x 3 columns]

# %%
cdrblog_0, cdrblog_1, cdrblog_2, cdrblog_3 =  (data_labels[data_labels["CDRGLOB"]==0].iloc[:,2]), \
                                              (data_labels[data_labels["CDRGLOB"]==1].iloc[:,2]), \
                                              (data_labels[data_labels["CDRGLOB"]==2].iloc[:,2]), \
                                              (data_labels[data_labels["CDRGLOB"]==3].iloc[:,2])

# %%
cdrglob_0_mean, cdrglob_1_mean, cdrglob_2_mean, cdrglob_3_mean =  cdrblog_0.mean(), \
                                                                  cdrblog_1.mean(), \
                                                                  cdrblog_2.mean(), \
                                                                  cdrblog_3.mean()

print('Hippocampus volume\'s mean for CDRBLOG 0 is {}'.format(cdrglob_0_mean))
print('Hippocampus volume\'s mean for CDRBLOG 1 is {}'.format(cdrglob_1_mean))
print('Hippocampus volume\'s mean for CDRBLOG 2 is {}'.format(cdrglob_2_mean))
print('Hippocampus volume\'s mean for CDRBLOG 3 is {}'.format(cdrglob_3_mean))
# Out:
# Hippocampus volume's mean for CDRBLOG 0 is 6.3125774058577395
# Hippocampus volume's mean for CDRBLOG 1 is 5.832705699481865
# Hippocampus volume's mean for CDRBLOG 2 is 5.333284285714286
# Hippocampus volume's mean for CDRBLOG 3 is 5.164641176470589

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].mean()
# Out:
#           HIP_VOL
# CDRGLOB
# 0        6.312577
# 1        5.832706
# 2        5.333284
# 3        5.164641

# %%
cdrglob_0_std, cdrglob_1_std, cdrglob_2_std, cdrglob_3_std =  cdrblog_0.std(), \
                                                              cdrblog_1.std(), \
                                                              cdrblog_2.std(), \
                                                              cdrblog_3.std()

print('Hippocampus volume\'s standard deviation for CDRBLOG 0 is {}'.format(cdrglob_0_std))
print('Hippocampus volume\'s standard deviation for CDRBLOG 1 is {}'.format(cdrglob_1_std))
print('Hippocampus volume\'s standard deviation for CDRBLOG 2 is {}'.format(cdrglob_2_std))
print('Hippocampus volume\'s standard deviation for CDRBLOG 3 is {}'.format(cdrglob_3_std))
# Out:
# Hippocampus volume's standard deviation for CDRBLOG 0 is 0.7469779954067012
# Hippocampus volume's standard deviation for CDRBLOG 1 is 0.8501738529428927
# Hippocampus volume's standard deviation for CDRBLOG 2 is 0.9512131800009151
# Hippocampus volume's standard deviation for CDRBLOG 3 is 1.1363401878722452

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].std()
# Out:
#           HIP_VOL
# CDRGLOB
# 0        0.746978
# 1        0.850174
# 2        0.951213
# 3        1.136340

# %%
data_labels.groupby('CDRGLOB').aggregate({'HIP_VOL': ['mean','std']})
# Out:
#           HIP_VOL
#              mean       std
# CDRGLOB
# 0        6.312577  0.746978
# 1        5.832706  0.850174
# 2        5.333284  0.951213
# 3        5.164641  1.136340

# %%
pd.pivot_table(data_labels, index=['CDRGLOB'], values='HIP_VOL', aggfunc=['mean', 'std']).plot(kind="bar")
plt.title("Hippocampus volume\'s mean & standard deviation\nwith respect to the level of Alzheimer's Disease")
plt.xlabel("level of Alzheimer's Disease")
# Out:
# Text(0.5, 0, "level of Alzheimer's Disease")
